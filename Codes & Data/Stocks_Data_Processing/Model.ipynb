# %%
print('STOCK PREDICTION USING RNN LSTM')
import numpy as np
import pandas as pd
from sklearn import preprocessing
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.layers import  Dropout
from keras.models import model_from_json
from keras.models import load_model
from keras import regularizers

import matplotlib.pyplot as pltb
import matplotlib.ticker as mtick
fmt = '$%.0f'
tick = mtick.FormatStrFormatter(fmt)

# %matplotlib inline

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import os

IMAGES_PATH=r"C:\Users\Shaaf Abdullah\Pictures\Plots_2"
def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
path = r"C:\Users\Shaaf Abdullah\FYP CODES\Stocks_Data"
directory=os.listdir(path)
Train_MSE={}
Test_MSE={}
Epochs={}

# %%
for file in directory:
    if file.endswith('.csv'):
        keras.backend.clear_session()
        data_csv = pd.read_csv(file)
        name=file
        data_csv[['Close']].plot()
        save_fig(name+'_closing_price_curve')
        plt.clf()
        percentage_of_data = 1.0
        data_to_use = int(percentage_of_data*(len(data_csv)-1))

         # 80% of data will be of training
        train_end = int(data_to_use*0.8)

        total_data = len(data_csv)
        print("total_data:", total_data)
        start = total_data - data_to_use

        # Currently doing prediction only for 1 step ahead
        steps_to_predict = 1

        #close, compund, neg, neu, pos, open, high, low, volume
        # Order -> 8,1,2,3,4,5,6,7,9
        yt = data_csv.iloc[start:total_data,8] #close
        yt1 = data_csv.iloc[start:total_data,1] #compund
        yt2 = data_csv.iloc[start:total_data,2] #neg
        yt3 = data_csv.iloc[start:total_data,3] #neu
        yt4 = data_csv.iloc[start:total_data,4] #pos
        yt5 = data_csv.iloc[start:total_data,5] #open
        yt6 = data_csv.iloc[start:total_data,6] #high
        yt7 = data_csv.iloc[start:total_data,7] #low
        vt = data_csv.iloc[start:total_data,9] #volume

        print("yt head (close) :")
        print(yt.head())
        #shift next day close and next day compund
        yt_ = yt.shift(-1) #shifted close
        yt1_ = yt1.shift(-1) #shifted compund

       #taking only: close, next_close, compund, next_compund, volume, open, high, low
        data = pd.concat([yt, yt_, yt1, yt1_, vt, yt5, yt6, yt7], axis=1)
        data.columns = ['yt', 'yt_', 'yt1', 'yt1_','vt', 'yt5', 'yt6', 'yt7']

        data = data.dropna()
     
        print(data[:10])
        # target variable - closed price
        # after shifting
        y = data['yt_'] #next_close

        # close, compund, next_compund, volume, open, high, low   
        cols = ['yt', 'yt1', 'yt1_', 'vt', 'yt5', 'yt6', 'yt7']
        x = data[cols]
        scaler_x = preprocessing.MinMaxScaler (feature_range=(-1, 1))
        x = np.array(x).reshape((len(x) ,len(cols)))
        x = scaler_x.fit_transform(x)

        scaler_y = preprocessing.MinMaxScaler (feature_range=(-1, 1))
        y = np.array (y).reshape ((len( y), 1))
        y = scaler_y.fit_transform (y)
        X_train = x[0 : train_end,]
        X_test = x[train_end+1 : len(x),]    
        y_train = y[0 : train_end] 
        y_test = y[train_end+1 : len(y)]  

        X_train = X_train.reshape (X_train. shape + (1,)) 
        X_test = X_test.reshape(X_test.shape + (1,))
        batch_size = 32

        nb_epoch = 200
        neurons = 25
        dropout = 0.1

        seed = 2016
        np.random.seed(seed)

        model = Sequential ()
        model.add(LSTM(neurons, return_sequences=True, activation='tanh', inner_activation='hard_sigmoid', input_shape=(len(cols), 1)))
        model.add(Dropout(dropout))
        model.add(LSTM(neurons, return_sequences=True,  activation='tanh'))
        model.add(Dropout(dropout))
        model.add(LSTM(neurons, activation='tanh'))
        model.add(Dropout(dropout))

        model.add(Dense(activity_regularizer=regularizers.l1(0.00001), output_dim=1, activation='linear'))
        model.add(Activation('tanh'))

        print(model.summary())
        model.compile(loss='mean_squared_error' , optimizer='RMSprop')
        history=model.fit(X_train, y_train, batch_size=batch_size, nb_epoch=nb_epoch, verbose=1, validation_split=0.2)
        score_train = model.evaluate(X_train, y_train, batch_size =1)
        score_test = model.evaluate(X_test, y_test, batch_size =1)
        
        Train_MSE[name]=round( score_train ,4)
        Test_MSE[name]=round( score_test ,4)
        Epochs[name]=nb_epoch
        
        print("in train MSE = ", round( score_train ,4)) 
        print("in test MSE = ", round(score_test ,4))
        model.save(name+"_model.h5")
        model.save_weights(name+"_weights.ckpt")
        print("Saved model to disk")
        pred = model.predict(X_test) 
        pred = scaler_y.inverse_transform(np.array(pred).reshape((len(pred), 1)))

        prediction_data = pred[-1]     

        print ("Inputs: {}".format(model.input_shape))
        print ("Outputs: {}".format(model.output_shape))
        print ("Actual input: {}".format(X_test.shape))
        print ("Actual output: {}".format(y_test.shape))

        print ("prediction data:")
        print (prediction_data)

        print ("actual data")
        X_test = scaler_x.inverse_transform(np.array(X_test).reshape((len(X_test), len(cols))))
        print (X_test)

        #########################################################################
        '''Plotting'''
        plt.plot(pred, label="predictions")

        y_test = scaler_y.inverse_transform(np.array(y_test).reshape((len( y_test), 1)))
        plt.plot([row[0] for row in y_test], label="actual")

        plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=2)

        ax = plt.axes()
        ax.yaxis.set_major_formatter(tick)
        save_fig(name+"_prediction_plot")
        plt.show()
        plt.clf()
        pd.DataFrame(history.history).plot(figsize=(8, 5))
        plt.grid(True)
        plt.gca().set_ylim(0, 1)
        save_fig(name+"_curves_plot")
        plt.show()
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        save_fig("Engro_learning_curves_plot")
        plt.show()

# %%
Train_MSE
# Out:
# {'AbbottLaboratoriesPakLtd .csv': 0.0669,
#  'AbdullahShahaGhaziSugerMillsLtd.csv': 0.0093,
#  'AdamSugarMillsLimited.csv': 0.0024,
#  'AGPLimited.csv': 0.0362,
#  'AgriautoIndustriesLtd.csv': 0.0292,
#  'AgritechLimited .csv': 0.0203,
#  'AkzoNobelPakistanLimitedAkzoNobelPakistanLimited.csv': 0.0003,
#  'AlAbbasSugarMillsLtd.csv': 0.0352,
#  'AlGhaziTractorsLimited.csv': 0.0728,
#  'AlliedBankLtd.csv': 0.0489,
#  'AlShaheerCorporation.csv': 0.0326,
#  'ArchromaPakistanLimited .csv': 0.0443,
#  'ArifHabibCorporationLtd.csv': 0.0491,
#  'ArujIndustriesLimited.csv': 0.143,
#  'AskariBankLimited.csv': 0.0347,
#  'AtlasBatteryLtd.csv': 0.0351,
#  'ATLASHONDA.csv': 0.0542,
#  'AtTahurLtd.csv': 0.0535,
#  'AttockCementPakLtd.csv': 0.0378,
#  'AttockPetroleumLimited.csv': 0.0032,
#  'AzgardNineLimited.csv': 0.0214,
#  'BabaFariedSugarMillsLtd.csv': 0.2998,
#  'BankAlfalahLtd.csv': 0.0601,
#  'BankAlHabibLtd.csv': 0.0753,
#  'BankislamiPakistanLtd.csv': 0.0123,
#  'BankOfPunjab.csv': 0.0485,
#  'BawanyAirProductsLtd.csv': 0.0538,
#  'BergerPaintsPakistanLtd.csv': 0.0946,
#  'BestwayCementLimited.csv': 0.0621,
#  'BifoIndustriesLtd.csv': 0.0359,
#  'BilalFibresLtd.csv': 0.0046,
#  'BleesedTextileLtd.csv': 0.0609,
#  'BurshaneLPGPakistanLimited.csv': 0.0367,
#  'BuxlyPaintsLtd.csv': 0.0024,
#  'ChakwalSpinningMillsLimited.csv': 0.0106,
#  'ChashmaSugarMillsLtd.csv': 0.0752,
#  'CheratCementCoLtd.csv': 0.0635,
#  'CloverPakistanLimited.csv': 0.0844,
#  'ColgatePalmolivePakLtd.csv': 0.1156,
#  'ColonyTextileMillsLtd.csv': 0.0322,
#  'CrescentTextileMillsLtd.csv': 0.0355,
#  'DandotCementCoLtd.csv': 0.0937,
#  'DawoodLawrencepurLtd.csv': 0.0523,
#  'DesconOxychemLtd.csv': 0.0708,
#  'DewanCementLimited.csv': 0.0659,
#  'DewanFarooqueSpinningMillsLtd.csv': 0.0647,
#  'DewanTextileMillsLtd.csv': 0.0121,
#  'DGKhanCementCoLtd .csv': 0.0329,
#  'DSIndustriesLtd.csv': 0.0819,
#  'DYNEAPak.csv': 0.0754,
#  'EngroCorporationLimited .csv': 0.1193,
#  'EngroFertilizersLimited.csv': 0.0422,
#  'EngroPolymerChemicalsLtd.csv': 0.0631,
#  'ExidePakistanLtd.csv': 0.0315,
#  'FaranSugarMillsLtd.csv': 0.0256,
#  'FatimaFertilizerCoLtd.csv': 0.007,
#  'FaujiCementCoLtd .csv': 0.0898,
#  'FaujiFertilizerBinQasimLtd.csv': 0.0646,
#  'FaujiFertilizerCoLtd.csv': 0.044,
#  'FaujiFoodsLimited.csv': 0.0128,
#  'FaysalBankLimited.csv': 0.012,
#  'FectoCementLtd.csv': 0.0903,
#  'Feroze1888MillsLtd.csv': 0.0993,
#  'FerozsonsLaboratoriesLtd .csv': 0.031,
#  'FlyingCementCompanyLtd.csv': 0.0294,
#  'FrieslandcampinaEngroPakistanLtd.csv': 0.0451,
#  'GadoonTextileMillsLtd.csv': 0.0801,
#  'GeneralTyre&RubberCo.csv': 0.0633,
#  'GeneralTyreRubberCo.csv': 0.0624,
#  'GhandharaIndustriesLtd.csv': 0.0847,
#  'GhaniAutomobileIndustries.csv': 0.0119,
#  'GhaniGlobalHoldingsLimited.csv': 0.0124,
#  'GhaziFabricsInternationalLtd.csv': 0.069,
#  'GlaxoSmithKlineHealthcarePakLtd.csv': 0.0248,
#  'GlaxoSmithKlinePakistanLtd.csv': 0.0413,
#  'GulAhmedTextileMillsLtd.csv': 0.0686,
#  'HabibBankLimited.csv': 0.1167,
#  'HabibMetropolitnBankLimited.csv': 0.049,
#  'HabibSugarMillsLtd.csv': 0.0959,
#  'HascolPetroleumLtd.csv': 0.0414,
#  'HBLInvestmentFund.csv': 0.1113,
#  'HighnoonLaboratoriesLtd.csv': 0.0707,
#  'HinopakMotorsLtd.csv': 0.0194,
#  'HiraTextileMillsLtd.csv': 0.0292,
#  'HiTechLubrcantsLimited.csv': 0.0798,
#  'HondaAtlasCars(Pakistan)LtdXD.csv': 0.0434,
#  'HuseinSugarMillsLimited.csv': 0.0603,
#  'IBLHealthCareLimited.csv': 0.0042,
#  'ICIPakistanLimited.csv': 0.0136,
#  'ImperialSugarLimited.csv': 0.0824,
#  'IndusDyeingManufacturing.csv': 0.3106,
#  'IndusMotorCompanyLtd.csv': 0.081,
#  'InterloopLimited.csv': 0.0254,
#  'IttehadChemicalLtd.csv': 0.0352,
#  'JDWSugarMillsLtd.csv': 0.0608,
#  'JSBankLimited.csv': 0.0525,
#  'KhyberTobaccoCoLtd.csv': 0.0802,
#  'KohatCementCoLtd.csv': 0.0431,
#  'KohinoorIndustriesLtd.csv': 0.0026,
#  'KohinoorMillsLtd.csv': 0.0161,
#  'KohinoorSpinningMillsLtd.csv': 0.01,
#  'KohinoorTextileMillsLtd.csv': 0.0522,
#  'LoadsLimited.csv': 0.0303,
#  'LotteChemicalPakistanLtd.csv': 0.0172,
#  'LuckyCementLimited.csv': 0.0372,
#  'MapleLeafCementFactoryLtd .csv': 0.1495,
#  'MaqboolTextileMillsLtd.csv': 0.0257,
#  'MasoodTextileMillsLtd.csv': 0.1022,
#  'MatcoFoodsLimited.csv': 0.0471,
#  'MCBBankLimited.csv': 0.0389,
#  'MeezanBankLimited.csv': 0.0585,
#  'MehranSugarMillsLtdXD.csv': 0.1746,
#  'MianTextileIndustriesLtd.csv': 0.0998,
#  'MillatTractorsLtd.csv': 0.0077,
#  'MirpurkhasSugarMillsLtd.csv': 0.074,
#  'MitchellsFruitFarmsLtd.csv': 0.0892,
#  'MurreeBreweryCompanyLtd.csv': 0.0306,
#  'NationalBankOfPakistan.csv': 0.012,
#  'NationalFoodsLtd.csv': 0.0032,
#  'NazirCottonMillsLtd.csv': 0.055,
#  'NimirIndustrialChemicalLtd.csv': 0.1015,
#  'NimirResinsLimited.csv': 0.0527,
#  'NishatChuniaLtd.csv': 0.0617,
#  'NishatMillsLtd.csv': 0.0426,
#  'NoonSugarMillsLtd.csv': 0.1051,
#  'OtsukaPakistanLtd.csv': 0.0489,
#  'PakElektronLtd.csv': 0.059,
#  'PakInternationalAirlineCorpLtd.csv': 0.0618,
#  'PakistanCablesLtd.csv': 0.0913,
#  'PakistanNationalShippingCo.csv': 0.0286,
#  'PakistanOxygenLimited.csv': 0.0346,
#  'PakistanStateOilCoLtd.csv': 0.0372,
#  'PakSuzukiMotorCo.Ltd.csv': 0.0927,
#  'PioneerCementLtd .csv': 0.0582,
#  'PowercementLimited.csv': 0.0354,
#  'PremiumTextileMillsLtd.csv': 0.0846,
#  'QuettaTextileMillsLtd.csv': 0.442,
#  'QuiceFoodIndustriesLtd.csv': 0.0118,
#  'RedcoTextileLtd.csv': 0.0627,
#  'RubyTextileMillsLtd.csv': 0.07,
#  'SafeMixConcreteLtd.csv': 0.0652,
#  'SaifTextileMillsLtd.csv': 0.1436,
#  'SakrandSugarMillsLtd.csv': 0.0455,
#  'SaminTextilesLtd.csv': 0.0052,
#  'SanofiAventisPakistanLtd.csv': 0.0537,
#  'SapphireTextileMillsLtd.csv': 0.1627,
#  'SazgarEngineeringWorks.csv': 0.0348,
#  'ServiceFabricsLtd.csv': 0.0326,
#  'ShadabTextileMillsLtd.csv': 0.1384,
#  'ShahmuradSugarMillsLtd.csv': 0.0961,
#  'ShahtajTextileLtd.csv': 0.1779,
#  'ShakarganjLimited.csv': 0.0472,
#  'ShellPakistanLtd.csv': 0.0988,
#  'ShezanInternationalLtd.csv': 0.0724,
#  'ShieldCorporationLtd.csv': 0.1315,
#  'SiemensEngCoLtd.csv': 0.0958,
#  'SilkBankLimited.csv': 0.0224,
#  'SindhAbadgarsSugarMillsLtd.csv': 0.1043,
#  'SitaraPeroxideLimited.csv': 0.0433,
#  'SoneriBankLtd.csv': 0.0394,
#  'StandardCharteredBankPakLtd.csv': 0.0469,
#  'SuiNorthernGasPipeLineLtd.csv': 0.0467,
#  'SuiSouthernGasCoLtd.csv': 0.0678,
#  'SummitBankLimited.csv': 0.0396,
#  'TandliawalaSugarMillsLtd.csv': 0.1481,
#  'TataTextileMillsLtd.csv': 0.0724,
#  'ThalLimited.csv': 0.0061,
#  'ThattaCementCompanyLtd.csv': 0.012,
#  'TheBankofKhyber.csv': 0.0343,
#  'TheSearleCompanyLtd.csv': 0.0433,
#  'TreetCorporationLtd.csv': 0.0247,
#  'TriStarMutualFundLtd.csv': 0.0405,
#  'UnitedBankLtd.csv': 0.1151,
#  'WahNobleChemicalsLtd.csv': 0.081,
#  'WAVESSingerPakistanLtd.csv': 0.0586,
#  'WyethPakistanLimited.csv': 0.0097,
#  'YousufWeavingMillsLimited.csv': 0.0318,
#  'ZahidjeeTextileMillsLtd.csv': 0.02,
#  'ZephyrTextileLimited.csv': 0.0851}

# %%
Test_MSE
# Out:
# {'AbbottLaboratoriesPakLtd .csv': 0.4322,
#  'AbdullahShahaGhaziSugerMillsLtd.csv': 0.1379,
#  'AdamSugarMillsLimited.csv': 0.1182,
#  'AGPLimited.csv': 0.0153,
#  'AgriautoIndustriesLtd.csv': 0.1191,
#  'AgritechLimited .csv': 0.1518,
#  'AkzoNobelPakistanLimitedAkzoNobelPakistanLimited.csv': 0.5834,
#  'AlAbbasSugarMillsLtd.csv': 0.0597,
#  'AlGhaziTractorsLimited.csv': 0.2885,
#  'AlliedBankLtd.csv': 0.0032,
#  'AlShaheerCorporation.csv': 0.3946,
#  'ArchromaPakistanLimited .csv': 0.1598,
#  'ArifHabibCorporationLtd.csv': 0.1691,
#  'ArujIndustriesLimited.csv': 0.5887,
#  'AskariBankLimited.csv': 0.1953,
#  'AtlasBatteryLtd.csv': 0.2387,
#  'ATLASHONDA.csv': 0.009,
#  'AtTahurLtd.csv': 0.3228,
#  'AttockCementPakLtd.csv': 0.2159,
#  'AttockPetroleumLimited.csv': 0.2259,
#  'AzgardNineLimited.csv': 0.3874,
#  'BabaFariedSugarMillsLtd.csv': 0.5928,
#  'BankAlfalahLtd.csv': 0.1548,
#  'BankAlHabibLtd.csv': 0.429,
#  'BankislamiPakistanLtd.csv': 0.2053,
#  'BankOfPunjab.csv': 0.6378,
#  'BawanyAirProductsLtd.csv': 0.0153,
#  'BergerPaintsPakistanLtd.csv': 0.0062,
#  'BestwayCementLimited.csv': 0.1237,
#  'BifoIndustriesLtd.csv': 0.3624,
#  'BilalFibresLtd.csv': 0.2295,
#  'BleesedTextileLtd.csv': 0.2294,
#  'BurshaneLPGPakistanLimited.csv': 0.3479,
#  'BuxlyPaintsLtd.csv': 0.166,
#  'ChakwalSpinningMillsLimited.csv': 0.1958,
#  'ChashmaSugarMillsLtd.csv': 0.4615,
#  'CheratCementCoLtd.csv': 0.1209,
#  'CloverPakistanLimited.csv': 0.1491,
#  'ColgatePalmolivePakLtd.csv': 0.1529,
#  'ColonyTextileMillsLtd.csv': 0.178,
#  'CrescentTextileMillsLtd.csv': 0.2514,
#  'DandotCementCoLtd.csv': 0.081,
#  'DawoodLawrencepurLtd.csv': 0.0022,
#  'DesconOxychemLtd.csv': 0.1363,
#  'DewanCementLimited.csv': 0.3241,
#  'DewanFarooqueSpinningMillsLtd.csv': 0.2063,
#  'DewanTextileMillsLtd.csv': 0.1195,
#  'DGKhanCementCoLtd .csv': 0.1251,
#  'DSIndustriesLtd.csv': 0.2842,
#  'DYNEAPak.csv': 0.3406,
#  'EngroCorporationLimited .csv': 0.5615,
#  'EngroFertilizersLimited.csv': 0.4765,
#  'EngroPolymerChemicalsLtd.csv': 0.1475,
#  'ExidePakistanLtd.csv': 0.0238,
#  'FaranSugarMillsLtd.csv': 0.2741,
#  'FatimaFertilizerCoLtd.csv': 0.1397,
#  'FaujiCementCoLtd .csv': 0.2373,
#  'FaujiFertilizerBinQasimLtd.csv': 0.2885,
#  'FaujiFertilizerCoLtd.csv': 0.2401,
#  'FaujiFoodsLimited.csv': 0.1106,
#  'FaysalBankLimited.csv': 0.1187,
#  'FectoCementLtd.csv': 0.5236,
#  'Feroze1888MillsLtd.csv': 0.0296,
#  'FerozsonsLaboratoriesLtd .csv': 0.3397,
#  'FlyingCementCompanyLtd.csv': 0.0121,
#  'FrieslandcampinaEngroPakistanLtd.csv': 0.3755,
#  'GadoonTextileMillsLtd.csv': 0.002,
#  'GeneralTyre&RubberCo.csv': 0.1518,
#  'GeneralTyreRubberCo.csv': 0.1434,
#  'GhandharaIndustriesLtd.csv': 0.2338,
#  'GhaniAutomobileIndustries.csv': 0.1386,
#  'GhaniGlobalHoldingsLimited.csv': 0.5727,
#  'GhaziFabricsInternationalLtd.csv': 0.2489,
#  'GlaxoSmithKlineHealthcarePakLtd.csv': 0.203,
#  'GlaxoSmithKlinePakistanLtd.csv': 0.5747,
#  'GulAhmedTextileMillsLtd.csv': 0.0894,
#  'HabibBankLimited.csv': 0.1684,
#  'HabibMetropolitnBankLimited.csv': 0.0033,
#  'HabibSugarMillsLtd.csv': 0.2893,
#  'HascolPetroleumLtd.csv': 0.352,
#  'HBLInvestmentFund.csv': 0.3615,
#  'HighnoonLaboratoriesLtd.csv': 0.0521,
#  'HinopakMotorsLtd.csv': 0.1533,
#  'HiraTextileMillsLtd.csv': 0.9556,
#  'HiTechLubrcantsLimited.csv': 0.0849,
#  'HondaAtlasCars(Pakistan)LtdXD.csv': 0.0241,
#  'HuseinSugarMillsLimited.csv': 0.0594,
#  'IBLHealthCareLimited.csv': 0.2436,
#  'ICIPakistanLimited.csv': 0.318,
#  'ImperialSugarLimited.csv': 0.0524,
#  'IndusDyeingManufacturing.csv': 0.3106,
#  'IndusMotorCompanyLtd.csv': 0.0638,
#  'InterloopLimited.csv': 0.3761,
#  'IttehadChemicalLtd.csv': 0.2483,
#  'JDWSugarMillsLtd.csv': 0.0005,
#  'JSBankLimited.csv': 0.0299,
#  'KhyberTobaccoCoLtd.csv': 0.2938,
#  'KohatCementCoLtd.csv': 0.7124,
#  'KohinoorIndustriesLtd.csv': 0.0067,
#  'KohinoorMillsLtd.csv': 0.1775,
#  'KohinoorSpinningMillsLtd.csv': 0.157,
#  'KohinoorTextileMillsLtd.csv': 0.2349,
#  'LoadsLimited.csv': 0.118,
#  'LotteChemicalPakistanLtd.csv': 0.1241,
#  'LuckyCementLimited.csv': 0.2709,
#  'MapleLeafCementFactoryLtd .csv': 0.3968,
#  'MaqboolTextileMillsLtd.csv': 0.5831,
#  'MasoodTextileMillsLtd.csv': 0.0282,
#  'MatcoFoodsLimited.csv': 0.1099,
#  'MCBBankLimited.csv': 0.2389,
#  'MeezanBankLimited.csv': 0.1507,
#  'MehranSugarMillsLtdXD.csv': 0.0757,
#  'MianTextileIndustriesLtd.csv': 0.2216,
#  'MillatTractorsLtd.csv': 0.1061,
#  'MirpurkhasSugarMillsLtd.csv': 0.0423,
#  'MitchellsFruitFarmsLtd.csv': 0.6896,
#  'MurreeBreweryCompanyLtd.csv': 0.0006,
#  'NationalBankOfPakistan.csv': 0.1257,
#  'NationalFoodsLtd.csv': 0.1074,
#  'NazirCottonMillsLtd.csv': 0.0493,
#  'NimirIndustrialChemicalLtd.csv': 0.0209,
#  'NimirResinsLimited.csv': 1.2372,
#  'NishatChuniaLtd.csv': 0.0887,
#  'NishatMillsLtd.csv': 0.4594,
#  'NoonSugarMillsLtd.csv': 0.0423,
#  'OtsukaPakistanLtd.csv': 0.3211,
#  'PakElektronLtd.csv': 0.1243,
#  'PakInternationalAirlineCorpLtd.csv': 1.1376,
#  'PakistanCablesLtd.csv': 0.1915,
#  'PakistanNationalShippingCo.csv': 0.0995,
#  'PakistanOxygenLimited.csv': 0.5135,
#  'PakistanStateOilCoLtd.csv': 0.0694,
#  'PakSuzukiMotorCo.Ltd.csv': 0.0119,
#  'PioneerCementLtd .csv': 0.1239,
#  'PowercementLimited.csv': 0.2445,
#  'PremiumTextileMillsLtd.csv': 0.0172,
#  'QuettaTextileMillsLtd.csv': 1.7533,
#  'QuiceFoodIndustriesLtd.csv': 0.1609,
#  'RedcoTextileLtd.csv': 0.5879,
#  'RubyTextileMillsLtd.csv': 0.0014,
#  'SafeMixConcreteLtd.csv': 0.049,
#  'SaifTextileMillsLtd.csv': 0.0038,
#  'SakrandSugarMillsLtd.csv': 0.1131,
#  'SaminTextilesLtd.csv': 0.2187,
#  'SanofiAventisPakistanLtd.csv': 0.1331,
#  'SapphireTextileMillsLtd.csv': 0.124,
#  'SazgarEngineeringWorks.csv': 0.0057,
#  'ServiceFabricsLtd.csv': 0.0028,
#  'ShadabTextileMillsLtd.csv': 0.1608,
#  'ShahmuradSugarMillsLtd.csv': 0.0903,
#  'ShahtajTextileLtd.csv': 0.3168,
#  'ShakarganjLimited.csv': 0.0103,
#  'ShellPakistanLtd.csv': 0.3213,
#  'ShezanInternationalLtd.csv': 0.8968,
#  'ShieldCorporationLtd.csv': 0.0336,
#  'SiemensEngCoLtd.csv': 0.6348,
#  'SilkBankLimited.csv': 0.0045,
#  'SindhAbadgarsSugarMillsLtd.csv': 0.4339,
#  'SitaraPeroxideLimited.csv': 0.6352,
#  'SoneriBankLtd.csv': 0.0009,
#  'StandardCharteredBankPakLtd.csv': 0.0098,
#  'SuiNorthernGasPipeLineLtd.csv': 0.1217,
#  'SuiSouthernGasCoLtd.csv': 0.1315,
#  'SummitBankLimited.csv': 0.2127,
#  'TandliawalaSugarMillsLtd.csv': 0.2251,
#  'TataTextileMillsLtd.csv': 0.0507,
#  'ThalLimited.csv': 0.0752,
#  'ThattaCementCompanyLtd.csv': 0.2065,
#  'TheBankofKhyber.csv': 0.1224,
#  'TheSearleCompanyLtd.csv': 0.2418,
#  'TreetCorporationLtd.csv': 0.5431,
#  'TriStarMutualFundLtd.csv': 0.2994,
#  'UnitedBankLtd.csv': 0.1681,
#  'WahNobleChemicalsLtd.csv': 0.0916,
#  'WAVESSingerPakistanLtd.csv': 0.2257,
#  'WyethPakistanLimited.csv': 0.1237,
#  'YousufWeavingMillsLimited.csv': 0.1119,
#  'ZahidjeeTextileMillsLtd.csv': 0.3454,
#  'ZephyrTextileLimited.csv': 0.0079}

# %%
Epochs
# Out:
# {'AbbottLaboratoriesPakLtd .csv': 200,
#  'AbdullahShahaGhaziSugerMillsLtd.csv': 200,
#  'AdamSugarMillsLimited.csv': 200,
#  'AGPLimited.csv': 200,
#  'AgriautoIndustriesLtd.csv': 200,
#  'AgritechLimited .csv': 200,
#  'AkzoNobelPakistanLimitedAkzoNobelPakistanLimited.csv': 200,
#  'AlAbbasSugarMillsLtd.csv': 200,
#  'AlGhaziTractorsLimited.csv': 200,
#  'AlliedBankLtd.csv': 200,
#  'AlShaheerCorporation.csv': 200,
#  'ArchromaPakistanLimited .csv': 200,
#  'ArifHabibCorporationLtd.csv': 200,
#  'ArujIndustriesLimited.csv': 200,
#  'AskariBankLimited.csv': 200,
#  'AtlasBatteryLtd.csv': 200,
#  'ATLASHONDA.csv': 200,
#  'AtTahurLtd.csv': 200,
#  'AttockCementPakLtd.csv': 200,
#  'AttockPetroleumLimited.csv': 200,
#  'AzgardNineLimited.csv': 200,
#  'BabaFariedSugarMillsLtd.csv': 200,
#  'BankAlfalahLtd.csv': 200,
#  'BankAlHabibLtd.csv': 200,
#  'BankislamiPakistanLtd.csv': 200,
#  'BankOfPunjab.csv': 200,
#  'BawanyAirProductsLtd.csv': 200,
#  'BergerPaintsPakistanLtd.csv': 200,
#  'BestwayCementLimited.csv': 200,
#  'BifoIndustriesLtd.csv': 200,
#  'BilalFibresLtd.csv': 200,
#  'BleesedTextileLtd.csv': 200,
#  'BurshaneLPGPakistanLimited.csv': 200,
#  'BuxlyPaintsLtd.csv': 200,
#  'ChakwalSpinningMillsLimited.csv': 200,
#  'ChashmaSugarMillsLtd.csv': 200,
#  'CheratCementCoLtd.csv': 200,
#  'CloverPakistanLimited.csv': 200,
#  'ColgatePalmolivePakLtd.csv': 200,
#  'ColonyTextileMillsLtd.csv': 200,
#  'CrescentTextileMillsLtd.csv': 200,
#  'DandotCementCoLtd.csv': 200,
#  'DawoodLawrencepurLtd.csv': 200,
#  'DesconOxychemLtd.csv': 200,
#  'DewanCementLimited.csv': 200,
#  'DewanFarooqueSpinningMillsLtd.csv': 200,
#  'DewanTextileMillsLtd.csv': 200,
#  'DGKhanCementCoLtd .csv': 200,
#  'DSIndustriesLtd.csv': 200,
#  'DYNEAPak.csv': 200,
#  'EngroCorporationLimited .csv': 200,
#  'EngroFertilizersLimited.csv': 200,
#  'EngroPolymerChemicalsLtd.csv': 200,
#  'ExidePakistanLtd.csv': 200,
#  'FaranSugarMillsLtd.csv': 200,
#  'FatimaFertilizerCoLtd.csv': 200,
#  'FaujiCementCoLtd .csv': 200,
#  'FaujiFertilizerBinQasimLtd.csv': 200,
#  'FaujiFertilizerCoLtd.csv': 200,
#  'FaujiFoodsLimited.csv': 200,
#  'FaysalBankLimited.csv': 200,
#  'FectoCementLtd.csv': 200,
#  'Feroze1888MillsLtd.csv': 200,
#  'FerozsonsLaboratoriesLtd .csv': 200,
#  'FlyingCementCompanyLtd.csv': 200,
#  'FrieslandcampinaEngroPakistanLtd.csv': 200,
#  'GadoonTextileMillsLtd.csv': 200,
#  'GeneralTyre&RubberCo.csv': 200,
#  'GeneralTyreRubberCo.csv': 200,
#  'GhandharaIndustriesLtd.csv': 200,
#  'GhaniAutomobileIndustries.csv': 200,
#  'GhaniGlobalHoldingsLimited.csv': 200,
#  'GhaziFabricsInternationalLtd.csv': 200,
#  'GlaxoSmithKlineHealthcarePakLtd.csv': 200,
#  'GlaxoSmithKlinePakistanLtd.csv': 200,
#  'GulAhmedTextileMillsLtd.csv': 200,
#  'HabibBankLimited.csv': 200,
#  'HabibMetropolitnBankLimited.csv': 200,
#  'HabibSugarMillsLtd.csv': 200,
#  'HascolPetroleumLtd.csv': 200,
#  'HBLInvestmentFund.csv': 200,
#  'HighnoonLaboratoriesLtd.csv': 200,
#  'HinopakMotorsLtd.csv': 200,
#  'HiraTextileMillsLtd.csv': 200,
#  'HiTechLubrcantsLimited.csv': 200,
#  'HondaAtlasCars(Pakistan)LtdXD.csv': 200,
#  'HuseinSugarMillsLimited.csv': 200,
#  'IBLHealthCareLimited.csv': 200,
#  'ICIPakistanLimited.csv': 200,
#  'ImperialSugarLimited.csv': 200,
#  'IndusDyeingManufacturing.csv': 200,
#  'IndusMotorCompanyLtd.csv': 200,
#  'InterloopLimited.csv': 200,
#  'IttehadChemicalLtd.csv': 200,
#  'JDWSugarMillsLtd.csv': 200,
#  'JSBankLimited.csv': 200,
#  'KhyberTobaccoCoLtd.csv': 200,
#  'KohatCementCoLtd.csv': 200,
#  'KohinoorIndustriesLtd.csv': 200,
#  'KohinoorMillsLtd.csv': 200,
#  'KohinoorSpinningMillsLtd.csv': 200,
#  'KohinoorTextileMillsLtd.csv': 200,
#  'LoadsLimited.csv': 200,
#  'LotteChemicalPakistanLtd.csv': 200,
#  'LuckyCementLimited.csv': 200,
#  'MapleLeafCementFactoryLtd .csv': 200,
#  'MaqboolTextileMillsLtd.csv': 200,
#  'MasoodTextileMillsLtd.csv': 200,
#  'MatcoFoodsLimited.csv': 200,
#  'MCBBankLimited.csv': 200,
#  'MeezanBankLimited.csv': 200,
#  'MehranSugarMillsLtdXD.csv': 200,
#  'MianTextileIndustriesLtd.csv': 200,
#  'MillatTractorsLtd.csv': 200,
#  'MirpurkhasSugarMillsLtd.csv': 200,
#  'MitchellsFruitFarmsLtd.csv': 200,
#  'MurreeBreweryCompanyLtd.csv': 200,
#  'NationalBankOfPakistan.csv': 200,
#  'NationalFoodsLtd.csv': 200,
#  'NazirCottonMillsLtd.csv': 200,
#  'NimirIndustrialChemicalLtd.csv': 200,
#  'NimirResinsLimited.csv': 200,
#  'NishatChuniaLtd.csv': 200,
#  'NishatMillsLtd.csv': 200,
#  'NoonSugarMillsLtd.csv': 200,
#  'OtsukaPakistanLtd.csv': 200,
#  'PakElektronLtd.csv': 200,
#  'PakInternationalAirlineCorpLtd.csv': 200,
#  'PakistanCablesLtd.csv': 200,
#  'PakistanNationalShippingCo.csv': 200,
#  'PakistanOxygenLimited.csv': 200,
#  'PakistanStateOilCoLtd.csv': 200,
#  'PakSuzukiMotorCo.Ltd.csv': 200,
#  'PioneerCementLtd .csv': 200,
#  'PowercementLimited.csv': 200,
#  'PremiumTextileMillsLtd.csv': 200,
#  'QuettaTextileMillsLtd.csv': 200,
#  'QuiceFoodIndustriesLtd.csv': 200,
#  'RedcoTextileLtd.csv': 200,
#  'RubyTextileMillsLtd.csv': 200,
#  'SafeMixConcreteLtd.csv': 200,
#  'SaifTextileMillsLtd.csv': 200,
#  'SakrandSugarMillsLtd.csv': 200,
#  'SaminTextilesLtd.csv': 200,
#  'SanofiAventisPakistanLtd.csv': 200,
#  'SapphireTextileMillsLtd.csv': 200,
#  'SazgarEngineeringWorks.csv': 200,
#  'ServiceFabricsLtd.csv': 200,
#  'ShadabTextileMillsLtd.csv': 200,
#  'ShahmuradSugarMillsLtd.csv': 200,
#  'ShahtajTextileLtd.csv': 200,
#  'ShakarganjLimited.csv': 200,
#  'ShellPakistanLtd.csv': 200,
#  'ShezanInternationalLtd.csv': 200,
#  'ShieldCorporationLtd.csv': 200,
#  'SiemensEngCoLtd.csv': 200,
#  'SilkBankLimited.csv': 200,
#  'SindhAbadgarsSugarMillsLtd.csv': 200,
#  'SitaraPeroxideLimited.csv': 200,
#  'SoneriBankLtd.csv': 200,
#  'StandardCharteredBankPakLtd.csv': 200,
#  'SuiNorthernGasPipeLineLtd.csv': 200,
#  'SuiSouthernGasCoLtd.csv': 200,
#  'SummitBankLimited.csv': 200,
#  'TandliawalaSugarMillsLtd.csv': 200,
#  'TataTextileMillsLtd.csv': 200,
#  'ThalLimited.csv': 200,
#  'ThattaCementCompanyLtd.csv': 200,
#  'TheBankofKhyber.csv': 200,
#  'TheSearleCompanyLtd.csv': 200,
#  'TreetCorporationLtd.csv': 200,
#  'TriStarMutualFundLtd.csv': 200,
#  'UnitedBankLtd.csv': 200,
#  'WahNobleChemicalsLtd.csv': 200,
#  'WAVESSingerPakistanLtd.csv': 200,
#  'WyethPakistanLimited.csv': 200,
#  'YousufWeavingMillsLimited.csv': 200,
#  'ZahidjeeTextileMillsLtd.csv': 200,
#  'ZephyrTextileLimited.csv': 200}

# %%
import csv
with open('Test_MSE.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    for key, value in Test_MSE.items():
        writer.writerow([key, value])
